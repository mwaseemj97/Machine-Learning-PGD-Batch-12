# %% [markdown]
# ## Linear Regression

# %%
import pandas as pd

# %%
df = pd.read_csv("data/Salary_Data.csv")

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
